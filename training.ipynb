# %%
#@title
# !git clone https://github.com/facebookresearch/BenchMARL
# %mkdir results
#@title
# %cd BenchMARL


#@title
# %pip install -U torch torchvision
# %pip install -e .
# %cd ..

# %%
# %pip install einops==0.6.1
# %pip install matplotlib

# %%
# %pip install pettingzoo[mpe]==1.23.0 supersuit
# %pip install gymnasium
# %pip install --upgrade "pettingzoo[mpe]"

# %%
# %pip install --upgrade torch
# %pip install --upgrade torchaudio
# %pip install --upgrade torchrl
# %pip install --upgrade torchvision
# %pip install --upgrade torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118
import torch
print("Torch version:",torch.__version__)

print("Is CUDA enabled?",torch.cuda.is_available())

# %%
#1 zestaw parametrów
config = {
        'sampling_device': 'cuda',
        'train_device': 'cuda',
        'buffer_device': 'cuda',
        'share_policy_params': True,
        'prefer_continuous_actions': False,
        'collect_with_grad': False,
        'parallel_collection': False,
        'gamma': 0.99,
        'lr': 0.01,
        'adam_eps': 1.0e-8,
        'clip_grad_norm': 0.5,
        'clip_grad_val': None,
        'soft_target_update': True,
        'polyak_tau': 0.005,
        'hard_target_update_frequency': 100,
        'exploration_eps_init': 1.0,
        'exploration_eps_end': 0.05,
        'exploration_anneal_frames': 1000000,
        'max_n_frames': 1000000,
        'on_policy_collected_frames_per_batch': 2048,
        'on_policy_n_envs_per_worker': 1,
        'on_policy_n_minibatch_iters': 4,
        'on_policy_minibatch_size': 64,
        'off_policy_collected_frames_per_batch': 100,
        'off_policy_n_envs_per_worker': 1,
        'off_policy_n_optimizer_steps': 100,
        'off_policy_train_batch_size': 512,
        'off_policy_memory_size': 1000000,
        'off_policy_init_random_frames': 50000,
        'off_policy_use_prioritized_replay_buffer': False,
        'off_policy_prb_alpha': 0.6,
        'off_policy_prb_beta': 0.4,
        'evaluation': True,
        'render': False,
        'evaluation_interval': 10000,
        'evaluation_episodes': 10,
        'evaluation_deterministic_actions': True,
        'project_name': 'benchmarl',
        'create_json': True,
        'save_folder': 'results1',
        'restore_file': None,
        'restore_map_location': None,
        'checkpoint_interval': 100,
        'checkpoint_at_end': True,
        'keep_checkpoints_num': 1,
        'max_n_iters': 5000,
        'loggers': [],

    }

# %%
#2 zestaw parametrów 
config = {
        'sampling_device': 'cuda',
        'train_device': 'cuda',
        'buffer_device': 'cuda',
        'share_policy_params': True,
        'prefer_continuous_actions': False,
        'collect_with_grad': False,
        'parallel_collection': False,
        'gamma': 0.99,
        'lr': 0.0005,
        'adam_eps': 1.0e-8,
        'clip_grad_norm': 0.5,
        'clip_grad_val': None,
        'soft_target_update': True,
        'polyak_tau': 0.005,
        'hard_target_update_frequency': 100,
        'exploration_eps_init': 1.0,
        'exploration_eps_end': 0.05,
        'exploration_anneal_frames': 1000000,
        'max_n_frames': 1000000,
        'on_policy_collected_frames_per_batch': 2048,
        'on_policy_n_envs_per_worker': 1,
        'on_policy_n_minibatch_iters': 4,
        'on_policy_minibatch_size': 64,
        'off_policy_collected_frames_per_batch': 100,
        'off_policy_n_envs_per_worker': 1,
        'off_policy_n_optimizer_steps': 100,
        'off_policy_train_batch_size': 512,
        'off_policy_memory_size': 1000000,
        'off_policy_init_random_frames': 50000,
        'off_policy_use_prioritized_replay_buffer': False,
        'off_policy_prb_alpha': 0.6,
        'off_policy_prb_beta': 0.4,
        'evaluation': True,
        'render': False,
        'evaluation_interval': 10000,
        'evaluation_episodes': 10,
        'evaluation_deterministic_actions': True,
        'project_name': 'benchmarl',
        'create_json': True,
        'save_folder': 'results2',
        'restore_file': None,
        'restore_map_location': None,
        'checkpoint_interval': 100,  # Changed from None to 0
        'checkpoint_at_end': True,
        'keep_checkpoints_num': 1,
        'max_n_iters': 5000,
        'loggers': [],

    }

# %%
#3 zestaw parametrów
config = {
        'sampling_device': 'cuda',
        'train_device': 'cuda',
        'buffer_device': 'cuda',
        'share_policy_params': True,
        'prefer_continuous_actions': False,
        'collect_with_grad': False,
        'parallel_collection': False,
        'gamma': 0.99,
        'lr': 0.0005,
        'adam_eps': 1.0e-8,
        'clip_grad_norm': 0.5,
        'clip_grad_val': None,
        'soft_target_update': True,
        'polyak_tau': 0.005,
        'hard_target_update_frequency': 100,
        'exploration_eps_init': 1.0,
        'exploration_eps_end': 0.05,
        'exploration_anneal_frames': 1000000,
        'max_n_frames': 1000000,
        'on_policy_collected_frames_per_batch': 2048,
        'on_policy_n_envs_per_worker': 1,
        'on_policy_n_minibatch_iters': 4,
        'on_policy_minibatch_size': 64,
        'off_policy_collected_frames_per_batch': 100,
        'off_policy_n_envs_per_worker': 1,
        'off_policy_n_optimizer_steps': 100,
        'off_policy_train_batch_size': 256,
        'off_policy_memory_size': 1000000,
        'off_policy_init_random_frames': 50000,
        'off_policy_use_prioritized_replay_buffer': False,
        'off_policy_prb_alpha': 0.6,
        'off_policy_prb_beta': 0.4,
        'evaluation': True,
        'render': False,
        'evaluation_interval': 10000,
        'evaluation_episodes': 10,
        'evaluation_deterministic_actions': True,
        'project_name': 'benchmarl',
        'create_json': True,
        'save_folder': 'results3',
        'restore_file': None,
        'restore_map_location': None,
        'checkpoint_interval': 100,  # Changed from None to 0
        'checkpoint_at_end': True,
        'keep_checkpoints_num': 1,
        'max_n_iters': 5000,
        'loggers': [],

    }

# %%
#4 zestaw parametrów 
config = {
        'sampling_device': 'cuda',
        'train_device': 'cuda',
        'buffer_device': 'cuda',
        'share_policy_params': True,
        'prefer_continuous_actions': False,
        'collect_with_grad': False,
        'parallel_collection': False,
        'gamma': 0.99,
        'lr': 0.001,
        'adam_eps': 1.0e-8,
        'clip_grad_norm': 0.5,
        'clip_grad_val': None,
        'soft_target_update': True,
        'polyak_tau': 0.005,
        'hard_target_update_frequency': 100,
        'exploration_eps_init': 1.0,
        'exploration_eps_end': 0.05,
        'exploration_anneal_frames': 1000000,
        'max_n_frames': 1000000,
        'on_policy_collected_frames_per_batch': 2048,
        'on_policy_n_envs_per_worker': 1,
        'on_policy_n_minibatch_iters': 4,
        'on_policy_minibatch_size': 64,
        'off_policy_collected_frames_per_batch': 100,
        'off_policy_n_envs_per_worker': 1,
        'off_policy_n_optimizer_steps': 100,
        'off_policy_train_batch_size': 256,
        'off_policy_memory_size': 1000000,
        'off_policy_init_random_frames': 50000,
        'off_policy_use_prioritized_replay_buffer': False,
        'off_policy_prb_alpha': 0.6,
        'off_policy_prb_beta': 0.4,
        'evaluation': True,
        'render': False,
        'evaluation_interval': 10000,
        'evaluation_episodes': 10,
        'evaluation_deterministic_actions': True,
        'project_name': 'benchmarl',
        'create_json': True,
        'save_folder': 'results4',
        'restore_file': None,
        'restore_map_location': None,
        'checkpoint_interval': 100,  # Changed from None to 0
        'checkpoint_at_end': True,
        'keep_checkpoints_num': 1,
        'max_n_iters': 5000,
        'loggers': [],

    }

# %%
#5 zestaw parametrów
config = {
        'sampling_device': 'cuda',
        'train_device': 'cuda',
        'buffer_device': 'cuda',
        'share_policy_params': True,
        'prefer_continuous_actions': False,
        'collect_with_grad': False,
        'parallel_collection': False,
        'gamma': 0.99,
        'lr': 0.01,
        'adam_eps': 1.0e-8,
        'clip_grad_norm': None,
        'clip_grad_val': None,
        'soft_target_update': True,
        'polyak_tau': 0.01,
        'hard_target_update_frequency': 100,
        'exploration_eps_init': 1.0,
        'exploration_eps_end': 0.05,
        'exploration_anneal_frames': 1000000,
        'max_n_frames': 1000000,
        'on_policy_collected_frames_per_batch': 2048,
        'on_policy_n_envs_per_worker': 1,
        'on_policy_n_minibatch_iters': 4,
        'on_policy_minibatch_size': 64,
        'off_policy_collected_frames_per_batch': 100,
        'off_policy_n_envs_per_worker': 1,
        'off_policy_n_optimizer_steps': 100,
        'off_policy_train_batch_size': 512,
        'off_policy_memory_size': 500000,
        'off_policy_init_random_frames': 50000,
        'off_policy_use_prioritized_replay_buffer': False,
        'off_policy_prb_alpha': 0.6,
        'off_policy_prb_beta': 0.4,
        'evaluation': True,
        'render': False,
        'evaluation_interval': 10000,
        'evaluation_episodes': 10,
        'evaluation_deterministic_actions': True,
        'project_name': 'benchmarl',
        'create_json': True,
        'save_folder': 'results5',
        'restore_file': None,
        'restore_map_location': None,
        'checkpoint_interval': 100,
        'checkpoint_at_end': True,
        'keep_checkpoints_num': 1,
        'max_n_iters': 5000,
        'loggers': [],

    }

# %%
#6 zestaw parametrów
config = {
        'sampling_device': 'cuda',
        'train_device': 'cuda',
        'buffer_device': 'cuda',
        'share_policy_params': True,
        'prefer_continuous_actions': True,
        'collect_with_grad': False,
        'parallel_collection': False,
        'gamma': 0.99,
        'lr': 0.0005,
        'adam_eps': 1.0e-8,
        'clip_grad_norm': 0.5,
        'clip_grad_val': None,
        'soft_target_update': True,
        'polyak_tau': 0.009,
        'hard_target_update_frequency': 100,
        'exploration_eps_init': 1.0,
        'exploration_eps_end': 0.05,
        'exploration_anneal_frames': 1000000,
        'max_n_frames': 1000000,
        'on_policy_collected_frames_per_batch': 2048,
        'on_policy_n_envs_per_worker': 1,
        'on_policy_n_minibatch_iters': 4,
        'on_policy_minibatch_size': 64,
        'off_policy_collected_frames_per_batch': 100,
        'off_policy_n_envs_per_worker': 1,
        'off_policy_n_optimizer_steps': 100,
        'off_policy_train_batch_size': 512,
        'off_policy_memory_size': 2000000,
        'off_policy_init_random_frames': 50000,
        'off_policy_use_prioritized_replay_buffer': False,
        'off_policy_prb_alpha': 0.6,
        'off_policy_prb_beta': 0.4,
        'evaluation': True,
        'render': False,
        'evaluation_interval': 10000,
        'evaluation_episodes': 10,
        'evaluation_deterministic_actions': True,
        'project_name': 'benchmarl',
        'create_json': True,
        'save_folder': 'results6',
        'restore_file': None,
        'restore_map_location': None,
        'checkpoint_interval': 100,
        'checkpoint_at_end': True,
        'keep_checkpoints_num': 1,
        'max_n_iters': 5000,
        'loggers': [],

    }

# %%
#7 zestaw parametrów 
config = {
        'sampling_device': 'cuda',
        'train_device': 'cuda',
        'buffer_device': 'cuda',
        'share_policy_params': True,
        'prefer_continuous_actions': False,
        'collect_with_grad': False,
        'parallel_collection': False,
        'gamma': 0.99,
        'lr': 0.01,
        'adam_eps': 1.0e-8,
        'clip_grad_norm': 0.5,
        'clip_grad_val': None,
        'soft_target_update': True,
        'polyak_tau': 0.01,
        'hard_target_update_frequency': 100,
        'exploration_eps_init': 1.5,
        'exploration_eps_end': 0.05,
        'exploration_anneal_frames': 250000,
        'max_n_frames': 1000000,
        'on_policy_collected_frames_per_batch': 2048,
        'on_policy_n_envs_per_worker': 1,
        'on_policy_n_minibatch_iters': 4,
        'on_policy_minibatch_size': 64,
        'off_policy_collected_frames_per_batch': 100,
        'off_policy_n_envs_per_worker': 1,
        'off_policy_n_optimizer_steps': 100,
        'off_policy_train_batch_size': 512,
        'off_policy_memory_size': 1000000,
        'off_policy_init_random_frames': 50000,
        'off_policy_use_prioritized_replay_buffer': False,
        'off_policy_prb_alpha': 0.6,
        'off_policy_prb_beta': 0.4,
        'evaluation': True,
        'render': False,
        'evaluation_interval': 10000,
        'evaluation_episodes': 10,
        'evaluation_deterministic_actions': True,
        'project_name': 'benchmarl',
        'create_json': True,
        'save_folder': 'results7',
        'restore_file': None,
        'restore_map_location': None,
        'checkpoint_interval': 100,
        'checkpoint_at_end': True,
        'keep_checkpoints_num': 1,
        'max_n_iters': 5000,
        'loggers': [],

    }

# %%
from benchmarl.algorithms import VdnConfig, QmixConfig
from benchmarl.benchmark import Benchmark
from benchmarl.environments import pettingzoo as MPETask
from benchmarl.experiment import ExperimentConfig
from benchmarl.models.mlp import MlpConfig
import os
from pathlib import Path
from benchmarl.eval_results import load_and_merge_json_dicts, Plotting
from matplotlib import pyplot as plt

from benchmarl.environments.pettingzoo.common import PettingZooTask

def run_benchmark(config):
    tasks = [PettingZooTask.SIMPLE_ADVERSARY.get_from_yaml(),
             PettingZooTask.SIMPLE_SPREAD.get_from_yaml(),
             PettingZooTask.SIMPLE_PUSH.get_from_yaml(),]



    experiment_config = ExperimentConfig(**config)


    vdn_config = VdnConfig(
        delay_value=True,
        loss_function="l2"
    )

    qmix_config = QmixConfig(
        delay_value=True,
        loss_function="l2",
        mixing_embed_dim=32
    )

    algorithm_configs = [qmix_config, vdn_config]

    model_config = MlpConfig(
        num_cells=[64, 64],
        layer_class="Linear",
        activation_class="ReLU"
    )

    critic_model_config = MlpConfig(
        num_cells=[64, 64],
        layer_class="Linear",
        activation_class="ReLU"
    )

    model_config = MlpConfig.get_from_yaml()
    critic_model_config = MlpConfig.get_from_yaml()

    benchmark = Benchmark(
        algorithm_configs=algorithm_configs,
        tasks=tasks,
        seeds={0, 1},
        experiment_config=experiment_config,
        model_config=model_config,
        critic_model_config=critic_model_config,
    )
    experiments = benchmark.get_experiments()
    experiments_json_files = []
    for experiment in experiments:
        exp_json_file = str(
            Path(experiment.folder_name) / Path(experiment.name + ".json")
        )
        experiments_json_files.append(exp_json_file)
        experiment.run()
    return experiments_json_files

# %%
experiments_json_files = run_benchmark(config)

raw_dict = load_and_merge_json_dicts(experiments_json_files)
